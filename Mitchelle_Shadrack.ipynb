# %%
import pandas as pd

# %%
df=pd.read_csv("genre_averages.csv")
df.head()
# Out:
#       Genre  averagerating  production_budget  domestic_gross  \
# 0  Thriller       5.843408       2.736711e+07    3.299267e+07
# 1       War       6.438462       2.310256e+07    1.967408e+07
# 2   History       6.829577       3.119592e+07    3.344521e+07
# 3   Romance       6.280126       2.055426e+07    2.973649e+07
# 4    Horror       5.351977       1.817108e+07    2.854655e+07
#
#    worldwide_gross  total_revenue   net_revenue          ROI
# 0     8.185753e+07   1.148502e+08  8.748310e+07   752.041710
# 1     4.257518e+07   6.224926e+07  3.914670e+07   119.234902
# 2     7.038875e+07   1.038340e+08  7.263805e+07   455.433233
# 3     6.367772e+07   9.341421e+07  7.285994e+07   479.335480
# 4     6.493768e+07   9.348423e+07  7.531315e+07  1164.154432

# %%
dt=pd.read_csv('working_data_file.csv')
dt.head()
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   7  Apr 27, 2018                       Avengers: Infinity War
#
#    production_budget  domestic_gross  worldwide_gross  total_revenue  \
# 0          425000000       760507625       2776345279     3536852904
# 1          410600000       241063875       1045663875     1286727750
# 2          350000000        42762350        149762350      192524700
# 3          330600000       459005868       1403013963     1862019831
# 4          300000000       678815482       2048134200     2726949682
#
#    net_revenue         ROI                    genres  averagerating  \
# 0   3111852904  732.200683                    Horror            6.1
# 1    876127750  213.377435  Action,Adventure,Fantasy            6.6
# 2   -157475300  -44.992943   Action,Adventure,Sci-Fi            6.0
# 3   1531419831  463.224389   Action,Adventure,Sci-Fi            7.3
# 4   2426949682  808.983227   Action,Adventure,Sci-Fi            8.5
#
#    runtime_minutes
# 0             93.0
# 1            136.0
# 2            113.0
# 3            141.0
# 4            149.0

# %%
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2752 entries, 0 to 2751
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 2752 non-null   int64
#  1   release_date       2752 non-null   object
#  2   movie              2752 non-null   object
#  3   production_budget  2752 non-null   int64
#  4   domestic_gross     2752 non-null   int64
#  5   worldwide_gross    2752 non-null   int64
#  6   total_revenue      2752 non-null   int64
#  7   net_revenue        2752 non-null   int64
#  8   ROI                2752 non-null   float64
#  9   genres             2752 non-null   object
#  10  averagerating      2752 non-null   float64
#  11  runtime_minutes    2752 non-null   float64
# dtypes: float64(3), int64(6), object(3)
# memory usage: 258.1+ KB

# %%
df1=pd.DataFrame(dt)
df1=df1.drop(columns=["production_budget","domestic_gross","worldwide_gross","total_revenue","net_revenue",'runtime_minutes'])
df1
# Out:
#       id  release_date                                        movie  \
# 0      1  Dec 18, 2009                                       Avatar
# 1      2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2      3   Jun 7, 2019                                 Dark Phoenix
# 3      4   May 1, 2015                      Avengers: Age of Ultron
# 4      7  Apr 27, 2018                       Avengers: Infinity War
# ...   ..           ...                                          ...
# 2747  62  Dec 31, 2014                         Stories of Our Lives
# 2748  68   Jul 6, 2001                                         Cure
# 2749  73  Jan 13, 2012                                    Newlyweds
# 2750  78  Dec 31, 2018                                       Red 11
# 2751  81  Sep 29, 2015                         A Plague So Pleasant
#
#               ROI                    genres  averagerating
# 0      732.200683                    Horror            6.1
# 1      213.377435  Action,Adventure,Fantasy            6.6
# 2      -44.992943   Action,Adventure,Sci-Fi            6.0
# 3      463.224389   Action,Adventure,Sci-Fi            7.3
# 4      808.983227   Action,Adventure,Sci-Fi            8.5
# ...           ...                       ...            ...
# 2747  -100.000000                     Drama            7.5
# 2748  1791.920000                     Drama            4.9
# 2749     1.866667              Comedy,Drama            6.4
# 2750  -100.000000    Horror,Sci-Fi,Thriller            5.6
# 2751  -100.000000     Drama,Horror,Thriller            5.4
#
# [2752 rows x 6 columns]

# %%
df1['release_date']=df1['release_date'].str.slice(0,3)
df1
# Out:
#       id release_date                                        movie  \
# 0      1          Dec                                       Avatar
# 1      2          May  Pirates of the Caribbean: On Stranger Tides
# 2      3          Jun                                 Dark Phoenix
# 3      4          May                      Avengers: Age of Ultron
# 4      7          Apr                       Avengers: Infinity War
# ...   ..          ...                                          ...
# 2747  62          Dec                         Stories of Our Lives
# 2748  68          Jul                                         Cure
# 2749  73          Jan                                    Newlyweds
# 2750  78          Dec                                       Red 11
# 2751  81          Sep                         A Plague So Pleasant
#
#               ROI                    genres  averagerating
# 0      732.200683                    Horror            6.1
# 1      213.377435  Action,Adventure,Fantasy            6.6
# 2      -44.992943   Action,Adventure,Sci-Fi            6.0
# 3      463.224389   Action,Adventure,Sci-Fi            7.3
# 4      808.983227   Action,Adventure,Sci-Fi            8.5
# ...           ...                       ...            ...
# 2747  -100.000000                     Drama            7.5
# 2748  1791.920000                     Drama            4.9
# 2749     1.866667              Comedy,Drama            6.4
# 2750  -100.000000    Horror,Sci-Fi,Thriller            5.6
# 2751  -100.000000     Drama,Horror,Thriller            5.4
#
# [2752 rows x 6 columns]

# %%
df1=df1.sort_values(by="ROI", ascending=False)
df1
# Out:
#       id release_date                     movie           ROI  \
# 2702  80          Jul               The Gallows  64320.884000
# 2530  47          Aug                     Bambi  43116.433566
# 2700  77          Oct  Night of the Living Dead  36894.849123
# 2628  37          Oct                 Halloween  35900.000000
# 2463  11          Nov                     Rocky  34123.514700
# ...   ..          ...                       ...           ...
# 2248  67          Feb  Enter the Dangerous Mind   -100.000000
# 2521  33          Mar           Ask Me Anything   -100.000000
# 2520  32          Aug                     Jesse   -100.000000
# 2519  31          Dec                    Trance   -100.000000
# 2751  81          Sep      A Plague So Pleasant   -100.000000
#
#                        genres  averagerating
# 2702  Horror,Mystery,Thriller            4.2
# 2530    Biography,Documentary            7.0
# 2700                   Horror            5.3
# 2628          Horror,Thriller            6.6
# 2463      Action,Comedy,Drama            6.1
# ...                       ...            ...
# 2248                 Thriller            5.2
# 2521                    Drama            6.1
# 2520       Action,Crime,Drama            4.9
# 2519      Crime,Drama,Mystery            6.9
# 2751    Drama,Horror,Thriller            5.4
#
# [2752 rows x 6 columns]

# %%
highest_return_month=df1.loc[df1['ROI'].idxmax(),'release_date']
print(f"The month with the highest return is:{highest_return_month}")
# Out:
# The month with the highest return is:Jul

# %%
top_20_months=df1.sort_values(by='ROI',ascending=False)
top_20_months=df1.head(20)
top_20_months
# Out:
#       id release_date                     movie           ROI  \
# 2702  80          Jul               The Gallows  64320.884000
# 2530  47          Aug                     Bambi  43116.433566
# 2700  77          Oct  Night of the Living Dead  36894.849123
# 2628  37          Oct                 Halloween  35900.000000
# 2463  11          Nov                     Rocky  34123.514700
# 2643  69          May            Graduation Day  19015.200000
# 2701  78          Feb     The Birth of a Nation  18990.909091
# 2464  12          Jan          The Devil Inside  15402.243500
# 2566  30          Nov                     Benji  12523.824000
# 2567  30          Nov                     Benji  12523.824000
# 2256  76          Feb                Cinderella  11920.393621
# 2407  63          Apr                 Insidious  10158.669067
# 2465  14          Apr                Unfriended   9615.384300
# 2589  60          Apr                      Home   8861.720200
# 2587  60          Apr                      Home   8861.720200
# 2586  60          Apr                      Home   8861.720200
# 2583  60          Apr                      Home   8861.720200
# 2585  60          Apr                      Home   8861.720200
# 2584  60          Apr                      Home   8861.720200
# 2582  60          Apr                      Home   8861.720200
#
#                           genres  averagerating
# 2702     Horror,Mystery,Thriller            4.2
# 2530       Biography,Documentary            7.0
# 2700                      Horror            5.3
# 2628             Horror,Thriller            6.6
# 2463         Action,Comedy,Drama            6.1
# 2643                    Thriller            5.0
# 2701     Biography,Drama,History            6.4
# 2464                      Horror            4.2
# 2566          Crime,Drama,Family            6.4
# 2567           Documentary,Sport            7.4
# 2256        Drama,Family,Fantasy            6.9
# 2407     Horror,Mystery,Thriller            6.9
# 2465     Horror,Mystery,Thriller            5.6
# 2589      Drama,Romance,Thriller            8.4
# 2587       Drama,Horror,Thriller            3.9
# 2586                       Drama            7.0
# 2583                       Drama            7.5
# 2585               Drama,Romance            6.8
# 2584  Adventure,Animation,Comedy            6.6
# 2582                       Drama            6.0

# %%
#Groupin by month and calculating monthly average return
monthly_returns=df1.groupby('release_date')['ROI'].mean().reset_index()
monthly_returns
# Out:
#    release_date         ROI
# 0           Apr  711.323671
# 1           Aug  523.219468
# 2           Dec  230.066251
# 3           Feb  562.681517
# 4           Jan  771.783130
# 5           Jul  756.544080
# 6           Jun  379.400636
# 7           Mar  297.114861
# 8           May  401.608026
# 9           Nov  678.967587
# 10          Oct  704.559009
# 11          Sep  281.294681

# %%
monthly_returns=monthly_returns.sort_values(by='ROI',ascending=False)
monthly_returns
# Out:
#    release_date         ROI
# 4           Jan  771.783130
# 5           Jul  756.544080
# 0           Apr  711.323671
# 10          Oct  704.559009
# 9           Nov  678.967587
# 3           Feb  562.681517
# 1           Aug  523.219468
# 8           May  401.608026
# 6           Jun  379.400636
# 7           Mar  297.114861
# 11          Sep  281.294681
# 2           Dec  230.066251

# %%
#Plotting the average returns by month
import matplotlib.pyplot as plt
plt.figure(figsize=(10,6))
plt.bar(monthly_returns['release_date'],monthly_returns['ROI'],color='purple')
plt.xlabel('Month')
plt.ylabel('Average Return')
plt.title('Average Movie Returns by Month')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# From the visualization above,it is evident that the top 5 monthly releases with the highest returns are January,July,April and October. We would therefore advise this month's to be the best time to make movie releases in order for them to have maximum impact and potentially capitalize on periods of higher consuming spending

# %%
df1=df1.sort_values(by="averagerating", ascending=False)
df1
# Out:
#       id release_date                           movie          ROI  \
# 1779  57          Mar                    The Runaways    -6.817842
# 608   16          Dec                         Traffic   592.515575
# 2216  29          May                        The Wall   109.944200
# 640    3          Nov                    Frankenstein   197.805760
# 487   28          Feb                       Dragonfly     0.212683
# ...   ..          ...                             ...          ...
# 1374  54          Feb                        Forsaken  -100.000000
# 641    3          Nov                    Frankenstein   197.805760
# 653   26          Dec                      Foodfight!   -99.836209
# 1068  44          Apr                      The Losers   113.821088
# 1538  48          Feb  Justin Bieber: Never Say Never  1223.446423
#
#                        genres  averagerating
# 1779                Adventure            9.2
# 608               Documentary            9.2
# 2216              Documentary            9.2
# 640                     Drama            9.0
# 487   Action,Adventure,Sci-Fi            9.0
# ...                       ...            ...
# 1374                   Horror            2.1
# 641              Drama,Horror            1.9
# 653   Action,Animation,Comedy            1.9
# 1068                    Drama            1.7
# 1538        Documentary,Music            1.6
#
# [2752 rows x 6 columns]

# %%
#Groupin by month and calculating monthly average rting
monthly_ratings=df1.groupby('release_date')['averagerating'].mean().reset_index()
monthly_ratings
# Out:
#    release_date  averagerating
# 0           Apr       6.200000
# 1           Aug       6.196476
# 2           Dec       6.243840
# 3           Feb       6.162371
# 4           Jan       6.086857
# 5           Jul       6.247343
# 6           Jun       6.281250
# 7           Mar       6.205652
# 8           May       6.296703
# 9           Nov       6.527193
# 10          Oct       6.234981
# 11          Sep       6.202542

# %%
monthly_ratings=monthly_ratings.sort_values(by="averagerating", ascending=False)
monthly_ratings
# Out:
#    release_date  averagerating
# 9           Nov       6.527193
# 8           May       6.296703
# 6           Jun       6.281250
# 5           Jul       6.247343
# 2           Dec       6.243840
# 10          Oct       6.234981
# 7           Mar       6.205652
# 11          Sep       6.202542
# 0           Apr       6.200000
# 1           Aug       6.196476
# 3           Feb       6.162371
# 4           Jan       6.086857

# %%
plt.figure(figsize=(10,6))
plt.plot(monthly_ratings['release_date'],monthly_ratings['averagerating'],marker='o',linestyle='-',color='b')
plt.xlabel('Months')
plt.ylabel('Average Rating')
plt.title('Average Ratings by Month')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %% [markdown]
# From the plot above,we can conclude that the months with the highest ratings are November,May,June and July.It thus advisable to release movies on the particular months.

# %%
#Groupin by Month and calculating average rating and ROI
monthly_stats=df1.groupby('release_date').agg({'ROI':'mean','averagerating':'mean'}).reset_index()
monthly_stats
# Out:
#    release_date         ROI  averagerating
# 0           Apr  711.323671       6.200000
# 1           Aug  523.219468       6.196476
# 2           Dec  230.066251       6.243840
# 3           Feb  562.681517       6.162371
# 4           Jan  771.783130       6.086857
# 5           Jul  756.544080       6.247343
# 6           Jun  379.400636       6.281250
# 7           Mar  297.114861       6.205652
# 8           May  401.608026       6.296703
# 9           Nov  678.967587       6.527193
# 10          Oct  704.559009       6.234981
# 11          Sep  281.294681       6.202542

# %%
#sorting months by average return and rating in descending order
monthly_stats=monthly_stats.sort_values(by=['ROI','averagerating'],ascending=False)
monthly_stats
# Out:
#    release_date         ROI  averagerating
# 4           Jan  771.783130       6.086857
# 5           Jul  756.544080       6.247343
# 0           Apr  711.323671       6.200000
# 10          Oct  704.559009       6.234981
# 9           Nov  678.967587       6.527193
# 3           Feb  562.681517       6.162371
# 1           Aug  523.219468       6.196476
# 8           May  401.608026       6.296703
# 6           Jun  379.400636       6.281250
# 7           Mar  297.114861       6.205652
# 11          Sep  281.294681       6.202542
# 2           Dec  230.066251       6.243840

# %%
fig, ax1 = plt.subplots(figsize=(12, 6)) 
color = 'tab:blue' 
ax1.set_xlabel('Month') 
ax1.set_ylabel('Average Return', color=color) 
Returns=ax1.plot(monthly_stats['release_date'], monthly_stats['ROI'], marker='o', linestyle='-', color=color, label='Average Return') 
ax1.tick_params(axis='y', labelcolor=color) 
ax2 = ax1.twinx() 
color = 'tab:red'
Ratings=ax2.set_ylabel('Average Rating', color=color) 
ax2.plot(monthly_stats['release_date'], monthly_stats['averagerating'], marker='o', linestyle='-', color=color, label='Average Rating') 
ax2.tick_params(axis='y', labelcolor=color) 
fig.tight_layout() 
plt.title('Average Movie Returns and Ratings by Month') 
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# From the plot above it is evident that high return movies do not necessarily have the highest ratings.Therefore,for a movie to get optimal results with a relatively good rating and high returns,it is preferrable to release it between the month of October and February

# %% [markdown]
# ### STATISTICS

# %%
import scipy.stats as stats
t_stat, p_value = stats.ttest_rel(df1['ROI'], df1['averagerating'])

# Print the results
print(f"T-statistic: {t_stat}")
print(f"P-value: {p_value}")

# Interpret the results
if p_value < 0.05:
    print("The is no relationship between Release_date and averagerating ")
else:
    print("The is a relationship between average rating and release_date.")
# Out:
# T-statistic: 11.870448749253795
# P-value: 9.89487637048856e-32
# The is no relationship between Release_date and averagerating

# %% [markdown]
# ### Linear Regression

# %%
df2 = pd.read_csv('budget_cleaned.csv')
df2.head()
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#    production_budget  domestic_gross  worldwide_gross  total_revenue
# 0          425000000       760507625       2776345279     3536852904
# 1          410600000       241063875       1045663875     1286727750
# 2          350000000        42762350        149762350      192524700
# 3          330600000       459005868       1403013963     1862019831
# 4          317000000       620181382       1316721747     1936903129

# %%
import statsmodels.api as sm
X = df2[["domestic_gross"]]
y = df2["total_revenue"]

# %%
model = sm.OLS(endog=y, exog=sm.add_constant(X))
model

# %%
results = model.fit()
results

# %%
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          total_revenue   R-squared:                       0.937
# Model:                            OLS   Adj. R-squared:                  0.937
# Method:                 Least Squares   F-statistic:                 8.617e+04
# Date:                Wed, 13 Nov 2024   Prob (F-statistic):               0.00
# Time:                        15:42:27   Log-Likelihood:            -1.1177e+05
# No. Observations:                5782   AIC:                         2.236e+05
# Df Residuals:                    5780   BIC:                         2.236e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const          -9.167e+06   9.28e+05     -9.875      0.000    -1.1e+07   -7.35e+06
# domestic_gross     3.4038      0.012    293.541      0.000       3.381       3.427
# ==============================================================================
# Omnibus:                     4217.069   Durbin-Watson:                   1.498
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           240954.835
# Skew:                           2.915   Prob(JB):                         0.00
# Kurtosis:                      34.083   Cond. No.                     9.39e+07
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 9.39e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# - domestic-gross expalins about 93% of the total profits

# %%
X = df2[["worldwide_gross"]]
y = df2["total_revenue"]

# %%
model = sm.OLS(endog=y, exog=sm.add_constant(X))
model

# %%
results = model.fit()
results

# %%
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          total_revenue   R-squared:                       0.990
# Model:                            OLS   Adj. R-squared:                  0.990
# Method:                 Least Squares   F-statistic:                 5.970e+05
# Date:                Wed, 13 Nov 2024   Prob (F-statistic):               0.00
# Time:                        15:44:34   Log-Likelihood:            -1.0634e+05
# No. Observations:                5782   AIC:                         2.127e+05
# Df Residuals:                    5780   BIC:                         2.127e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const            8.326e+06   3.49e+05     23.867      0.000    7.64e+06    9.01e+06
# worldwide_gross     1.3667      0.002    772.635      0.000       1.363       1.370
# ==============================================================================
# Omnibus:                     1330.540   Durbin-Watson:                   1.462
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            64551.267
# Skew:                          -0.170   Prob(JB):                         0.00
# Kurtosis:                      19.365   Cond. No.                     2.23e+08
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.23e+08. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# - worldwide_gross explains about 99% of the profit.
